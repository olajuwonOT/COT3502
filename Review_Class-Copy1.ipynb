# %%
#Some Concepts we learnt in class

# %% [markdown]
# # Flowcharts

# %% [markdown]
# ![image1.png](attachment:image1.png)

# %% [markdown]
# Basic Conditionals: Python's if, elif, and else dictate code execution based on conditions.
#
# Flowcharts and pseudocode: These are beneficial tool for visualizing complex logic flows and making your code readable through comments.
#
# Nested vs. Sequential Checks: Context determines whether nested or sequential conditionals are more suitable.
#
# Duck Typing and Error Handeling: Python values an object's behavior more than its explicit type. Errors can be handled in varied methods

# %% [markdown]
# # While loop - conditional-controlled loop

# %% [markdown]
# ![image_2.png](attachment:image_2.png)

# %% [markdown]
# ## For loops
# The concept of loops is a cornerstone for automating repetitive tasks - for loops are sequence-based.
#
# A for loop in Python iterates over sequences like lists, tuples, or strings. Here's the general structure:

# %% [raw]
# for element in sequence:
#   code block

# %% [markdown]
# ## Functions

# %% [markdown]
# Functions allow us to encapsulate a piece of code, making it reusable and modular.
# Instead of repeating the same code multiple times, we can define it once in a function and call the function whenever needed.

# %% [raw]
# def function_name(parameters):
#     # function body
#     return output

# %% [markdown]
# ## Some Practice Problems

# %% [markdown]
# ### Implement a function called greatest_common_divisor() that determines the greatest common divisor of two numbers.

# %%
#The algorithm iteratively takes the remainder of the larger number 
#divided by the smaller number until the remainder becomes zero.

# %%
gcd(16, 4)
# Out:
# 4

# %% [markdown]
# ### Write a function that takes a natural number as an argument and returns a list containing the prime factorization of that number. Present the solution in the form of a function called Calculate()

# %%
# Out:
# The prime factorization of 84 is: [2, 2, 3, 7]

# %% [markdown]
# ### Find the difference between the sum of the squares of the first one hundred natural numbers and the square of the sum.

# %%
#[i**2 for i in range(0,100)]

# %%
# Out:
# The difference between the sum of the squares and the square of the sum for the first 10 natural numbers is: 25164150

# %% [markdown]
# You are given the following information, but you may prefer to do some research for yourself.
#
# 1 Jan 1900 was a Monday.
# Thirty days has September,
# April, June and November.
# All the rest have thirty-one,
# Saving February alone,
# Which has twenty-eight, rain or shine.
# And on leap years, twenty-nine.
# A leap year occurs on any year evenly divisible by 4, but not on a century unless it is divisible by 400.
#
# ## Define a function that counts how many Sundays fell on the first of the month during the twentieth century (1 Jan 1901 to 31 Dec 2000)?
